# %%
import os.path
import uuid
import json
import importlib
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from catboost import CatBoostClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

from config import *
from op import OPReader
import zenmoney
import rules

OP_FAMILY_ID = '50ca9746-f13a-4b67-adbb-1fe8f7f28439'
OP_EUR_ID    = 'f02f21c3-2686-4c78-a3da-cc4c776fba93'
OP_MONEY_BOX = '052b718d-74f1-4e25-b1fa-5f7b9e7a7ca4'

FILENAME          = 'zenmoney.json'
MODEL_PATH        = 'model.cbm'
FEATURES_PATH     = 'model_features.json'

TRAIN_START       = '2024-01-01'
TRAIN_END         = '2024-08-31'
MIN_CLASS_SAMPLES = 10

# %%
def load_or_sync(filename, token, out_diff=None):
    conn = zenmoney.ZenConnection(token)
    if os.path.exists(filename):
        print('Syncing...')
        zen = zenmoney.Zenmoney.load(filename)
        conn.sync_timestamp = zen.server_timestamp
        diff = conn.sync(diff=out_diff)
        zen.apply_diff(diff)
        zen.write(filename)
        print('Sync done.')
    else:
        print('Getting initial data...')
        zen = zenmoney.Zenmoney(conn.sync())
        zen.write(filename)
        print('Done.')
    return zen


def get_updates(zen, _filename, _acc_id):
    def check(zen_txn, op_txn):
        fields = ['date']
        if op_txn['income'] > 0:
            fields += ['income', 'incomeAccount']
        else:
            fields += ['outcome', 'outcomeAccount']
        for field in fields:
            if zen_txn.get(field) != op_txn.get(field):
                return False
        if zen_txn.get('deleted'):
            print(op_txn)
        return True

    diff = {'transaction': []}
    op = OPReader(filename=_filename, zen_id=_acc_id, instrument_id=3)
    for line in op.read():
        if not any(check(x, line) for x in zen.transaction):
            line.update({
                'id': str(uuid.uuid4()),
                'created': line['changed'],
                'user': ZEN_USER,
                'deleted': False,
                'tag': [],
                'merchant': None,
                'reminderMarker': None,
                'incomeBankID': None,
                'outcomeBankID': None,
                'opIncome': None,
                'opOutcome': None,
                'opIncomeInstrument': None,
                'opOutcomeInstrument': None,
                'latitude': None,
                'longitude': None,
            })
            diff['transaction'].append(line)
    return diff


def load_transactions(zen):
    """Load zen transactions into a cleaned DataFrame with parsed dates."""
    df = pd.DataFrame(zen.transaction)
    df['date'] = pd.to_datetime(df['date'])
    return df


def filter_df(df, start=None, end=None, exclude_transfers=True, exclude_deleted=True):
    """Filter transactions by date range and common flags."""
    mask = pd.Series(True, index=df.index)
    if start:
        mask &= df['date'] >= pd.Timestamp(start)
    if end:
        mask &= df['date'] <= pd.Timestamp(end)
    if exclude_deleted:
        mask &= df['deleted'] == False
    if exclude_transfers:
        mask &= ~((df['income'] > 0) & (df['outcome'] > 0))
    return df[mask].copy()


def add_features(df, op_family_id=OP_FAMILY_ID):
    """Add date-based and account-based ML features."""
    df = df.copy()
    df['day_of_week'] = df['date'].dt.dayofweek
    df['month']       = df['date'].dt.month
    df['day']         = df['date'].dt.day
    df['is_family']   = (
        (df['incomeAccount'] == op_family_id) |
        (df['outcomeAccount'] == op_family_id)
    ).astype(int)
    return df

# %%
importlib.reload(rules)
from rules import MANUAL_TAGS, _tag_name_map, filter_prediction

zen = load_or_sync(FILENAME, ZEN_API_TOKEN)
df  = load_transactions(zen)

tag_map     = {t['id']: t['title'] for t in zen.tag}
account_map = {a['id']: a['title'] for a in zen.account}
tag_name_map = _tag_name_map(zen)

print(f'Loaded {len(df)} transactions')
# Out:
# Syncing...
# Sync done.
# Loaded 32667 transactions

# %%
df_train = filter_df(df, start=TRAIN_START, end=TRAIN_END)
df_train['tag_first'] = df_train['tag'].apply(
    lambda x: x[0] if isinstance(x, list) and len(x) > 0 else None
)
df_train = df_train.dropna(subset=['tag_first'])
df_train = df_train[~df_train['tag_first'].map(tag_name_map).isin(MANUAL_TAGS)]

records = df_train.to_dict('records')
valid = [filter_prediction(t['tag_first'], t, zen) == t['tag_first'] for t in records]
before = len(df_train)
df_train = df_train[valid]
print(f'Dropped {before - len(df_train)} rule-violating rows, {len(df_train)} remain')

class_counts = df_train['tag_first'].value_counts()
df_train = df_train[df_train['tag_first'].isin(class_counts[class_counts >= MIN_CLASS_SAMPLES].index)]

df_train = add_features(df_train)

num_features   = ['day_of_week', 'month', 'day', 'income', 'outcome', 'is_family']
cat_col_names  = ['incomeAccount', 'outcomeAccount', 'merchant']
text_col_names = ['originalPayee']

all_features  = [f for f in num_features + cat_col_names + text_col_names if f in df_train.columns]
cat_features  = [f for f in cat_col_names  if f in all_features]
text_features = [f for f in text_col_names if f in all_features]

X = df_train[all_features].copy()
X[cat_features + text_features] = X[cat_features + text_features].astype(str).fillna('NA')
y = df_train['tag_first']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y
)

model = CatBoostClassifier(
    iterations=200, verbose=100,
    cat_features=cat_features, text_features=text_features,
)
model.fit(X_train, y_train)

y_pred = model.predict(X_test)
y_test_names = y_test.map(tag_map)
y_pred_names = pd.Series(y_pred.ravel(), index=y_test.index).map(tag_map)
print(classification_report(y_test_names, y_pred_names))

model.save_model(MODEL_PATH)
with open(FEATURES_PATH, 'w') as f:
    json.dump({
        'all_features':  all_features,
        'cat_features':  cat_features,
        'text_features': text_features,
        'op_family_id':  OP_FAMILY_ID,
    }, f)
print(f'Model saved to {MODEL_PATH}')
# Out:
# Dropped 15 rule-violating rows, 1146 remain
# Learning rate set to 0.306139
# 0:	learn: 1.8316178	total: 262ms	remaining: 52.2s
# 100:	learn: 0.3904428	total: 13s	remaining: 12.7s
# 199:	learn: 0.1610634	total: 25.7s	remaining: 0us
#                           precision    recall  f1-score   support
#
#                 B Донаты       0.00      0.00      0.00         3
#                    B Еда       0.83      0.68      0.75        28
#                    B ЖКХ       1.00      0.50      0.67         2
#             B Здоровье Х       0.71      1.00      0.83         5
#            B Карманные П       0.60      0.86      0.71         7
#            B Карманные Х       0.60      0.88      0.72        33
# B Концерты/театры/выезды       0.00      0.00      0.00         4
#               B Подписки       0.43      0.82      0.56        11
#              B Рестораны       0.40      0.29      0.33         7
#      B Спорт/образование       1.00      1.00      1.00        12
# ...

# %%
df_audit = filter_df(df, start=TRAIN_START, end=TRAIN_END)
df_audit['tag_first'] = df_audit['tag'].apply(
    lambda x: x[0] if isinstance(x, list) and len(x) > 0 else None
)
df_audit = df_audit.dropna(subset=['tag_first'])

violations = []
for txn in df_audit.to_dict('records'):
    tag_id  = txn['tag_first']
    allowed = filter_prediction(tag_id, txn, zen)
    if allowed != tag_id:
        violations.append({
            'date':    txn['date'],
            'amount':  f"{'-' if txn['outcome'] > 0 else '+'}{txn['outcome'] if txn['outcome'] > 0 else txn['income']:.2f}",
            'account': account_map.get(txn.get('outcomeAccount') or txn.get('incomeAccount'), '?'),
            'payee':   txn.get('originalPayee') or txn.get('payee') or '',
            'tag':     tag_name_map.get(tag_id, tag_id),
            'reason':  'suppressed (MANUAL_TAG)' if allowed is None and tag_name_map.get(tag_id) in rules.MANUAL_TAGS
                       else 'wrong account',
        })

df_violations = pd.DataFrame(violations)
print(f'{len(violations)} violation(s) in training window\n')
if not df_violations.empty:
    display(df_violations.sort_values(['reason', 'tag', 'date']))
# Out:
# 15 violation(s) in training window
#          date  amount    account                 payee            tag  \
# 4  2024-01-05  -61.38    Revolut       Toolon Apteekki   B Здоровье П
# 5  2024-06-14  -85.20     OP EUR                   NaN   B Здоровье П
# 3  2024-01-08  -10.98    Revolut  Heroku* Dec-90941444  B Карманные П
# 2  2024-03-10   -1.00    Revolut           Mc Donald's  B Карманные П
# 1  2024-04-28   -8.40    Revolut          Yp-Bistro Oy  B Карманные П
# 0  2024-08-07  -11.01    Revolut  Heroku* Jul-96948373  B Карманные П
# 14 2024-01-27   -2.45  OP Family                   NaN  B Карманные Х
# 11 2024-04-09   -5.09  OP Family                   NaN  B Карманные Х
# 12 2024-04-09   -4.62  OP Family                   NaN  B Карманные Х
# 13 2024-04-09   -1.95  OP Family                   NaN  B Карманные Х
# 10 2024-04-18   -3.90  OP Family                   NaN  B Карманные Х
# 7  2024-05-04   -6.48  OP Family                   NaN  B Карманные Х
# ...

# %%
with open(FEATURES_PATH) as f:
    feat = json.load(f)

all_features  = feat['all_features']
cat_features  = feat['cat_features']
text_features = feat['text_features']

model = CatBoostClassifier()
model.load_model(MODEL_PATH)

today         = pd.Timestamp.today().normalize()
one_month_ago = today - pd.DateOffset(months=1)
df_recent     = filter_df(df, start=str(one_month_ago.date()))
df_recent     = add_features(df_recent, feat['op_family_id'])

X_recent = df_recent[all_features].copy()
X_recent[cat_features + text_features] = X_recent[cat_features + text_features].astype(str).fillna('NA')

y_pred      = model.predict(X_recent).ravel()
txn_records = df_recent.to_dict('records')

df_recent['predicted_tag'] = [
    filter_prediction(tag_id, txn, zen)
    for tag_id, txn in zip(y_pred, txn_records)
]
df_recent['predicted_tag_name'] = df_recent['predicted_tag'].map(tag_map)

output_cols = ['date', 'originalPayee', 'comment', 'payee', 'predicted_tag_name']
df_recent[[c for c in output_cols if c in df_recent.columns]]

# %%
df = load_transactions(load_or_sync(FILENAME, ZEN_API_TOKEN))

UNTAGGED_LABEL = 'без категории'
UNTAGGED_COLOR = '#FF3131'

df_plot = filter_df(df[df['date'].dt.year.isin([2024, 2025, 2026])])
df_plot['month'] = df_plot['date'].dt.to_period('M')

df_tagged   = df_plot[df_plot['tag'].apply(lambda x: isinstance(x, list) and len(x) > 0)].copy()
df_tagged   = df_tagged.explode('tag')
df_tagged['tag_name'] = df_tagged['tag'].map(tag_map)

df_untagged = df_plot[df_plot['tag'].apply(lambda x: not (isinstance(x, list) and len(x) > 0))].copy()
df_untagged['tag_name'] = UNTAGGED_LABEL

combined    = pd.concat([df_tagged[['month', 'tag_name']], df_untagged[['month', 'tag_name']]])
pivot       = combined.groupby(['month', 'tag_name']).size().unstack(fill_value=0).sort_index()

tagged_cols = [c for c in pivot.columns if c != UNTAGGED_LABEL]
pivot       = pivot[tagged_cols + [UNTAGGED_LABEL]]

palette = cm.get_cmap('tab20', len(tagged_cols))
colors  = [palette(i) for i in range(len(tagged_cols))] + [UNTAGGED_COLOR]

fig, ax = plt.subplots(figsize=(18, 6))
pivot.plot(kind='bar', stacked=True, ax=ax, width=0.85, color=colors)
ax.set_title('Transactions per month by category (2024\u20132026, excl. transfers)')
ax.set_xlabel('')
ax.set_ylabel('Transaction count')
ax.legend(bbox_to_anchor=(1.01, 1), loc='upper left', fontsize=8)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# Syncing...
# Updated transaction: 143 item(s)
# Sync done.
# C:\Users\eltha\AppData\Local\Temp\ipykernel_22984\2745809297.py:22: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   palette = cm.get_cmap('tab20', len(tagged_cols))

# %%
rv = pd.read_csv('review_output.csv')
rv['reviewed_cat'] = rv['reviewed_cat'].fillna('')

skipped   = rv[rv['reviewed_cat'] == '']
confirmed = rv[(rv['reviewed_cat'] == rv['predicted_cat']) & (rv['reviewed_cat'] != '')]
changed   = rv[(rv['reviewed_cat'] != rv['predicted_cat']) & (rv['reviewed_cat'] != '')]

print(f'Total:     {len(rv)}')
print(f'Confirmed: {len(confirmed)}')
print(f'Changed:   {len(changed)}')
print(f'Skipped:   {len(skipped)}')

print('--- Changed predictions ---')
display(changed[['transaction_id', 'predicted_cat', 'reviewed_cat']].reset_index(drop=True))

print('--- Reviewed category breakdown ---')
display(rv[rv['reviewed_cat'] != '']['reviewed_cat'].value_counts().rename('count').to_frame())
